# %% [markdown]
# <a href="https://colab.research.google.com/github/harikab5/MAIN-FLOW-DATASCIENCE-INTERNSHIP-TASK-6/blob/main/MAIN_FLOW_DATASCIENCE_TASK_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                   MAIN FLOW SERVICES AND TECHNOLOGIES
#                   DATA SCIENCE WITH PYTHON INTERSHIP
#                              TASK-6
#
#                   DESCRIPTION:
#                   Apply advanced statistical and analytical
#                   methods to solve complex problems
#
#                   RESPONSIBILITY:
#                   1. Implement time series analysis for
#                      forecasting trends and seasonality.
#                   2. Perform sentiment analysis or text mining on
#                      unstructured data.
#                   3. Explore clustering or classification
#                      techniques for segmentation and pattern
#                      recognition

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('/content/disney_plus_titles task 6.csv')

# %%
data.head()
# Out:
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
# ...

# %%
data.tail()
# Out:
#      show_id     type                   title             director  \
# 1363   s1364    Movie  The Sword in the Stone  Wolfgang Reitherman
# 1364   s1365    Movie         Those Calloways         Norman Tokar
# 1365   s1366  TV Show    Disney Kirby Buckets                  NaN
# 1366   s1367  TV Show          Disney Mech-X4                  NaN
# 1367   s1368  TV Show      Imagination Movers                  NaN
#
#                                                    cast        country  \
# 1363  Sebastian Cabot, Karl Swenson, Rickie Sorensen...  United States
# 1364  Brian Keith, Vera Miles, Brandon de Wilde, Wal...  United States
# 1365  Jacob Bertrand, Mekai Curtis, Cade Sutton, Oli...  United States
# 1366  Nathaniel Potvin, Raymond Cham, Kamran Lucas, ...         Canada
# 1367  Rich Collins, Dave Poche, Scott Durbin, Scott ...  United States
#
#            date_added  release_year rating   duration  \
# 1363  October 1, 2019          1963      G     80 min
# ...

# %%
data.columns.values
# Out:
# array(['show_id', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'description'], dtype=object)

# %%
data.isna().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        440
# cast            174
# country         175
# date_added        3
# release_year      0
# rating            2
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1368 non-null   object
#  1   type          1368 non-null   object
#  2   title         1368 non-null   object
#  3   director      928 non-null    object
#  4   cast          1194 non-null   object
#  5   country       1193 non-null   object
#  6   date_added    1365 non-null   object
#  7   release_year  1368 non-null   int64
#  8   rating        1366 non-null   object
#  9   duration      1368 non-null   object
#  10  listed_in     1368 non-null   object
#  11  description   1368 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 128.4+ KB

# %%
data.describe()
# Out:
#        release_year
# count   1368.000000
# mean    2002.348684
# std       22.127559
# min     1928.000000
# 25%     1998.000000
# 50%     2011.000000
# 75%     2018.000000
# max     2021.000000

# %%
df=data.copy()

# %%
print(df.isnull().sum())
df = df.dropna()
df['release_year'] = pd.to_datetime(df['release_year'], format='%Y')
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
questions = ["1.What is the distribution of content types in the dataset?",
             "2.Who are the top three directors with the most content in the dataset?",
             "3.Which country has produced the highest number of movies and TV shows combined in the dataset?",
             "4.What is the average duration of Movies in the dataset?",
             "5.What are the top three genres by the number of titles in the dataset?",
             "6.What is the oldest Movie or TV Show in the dataset?",
             "7.What is the distribution of content ratings in the dataset?"]
questions
# Out:
# ['1.What is the distribution of content types in the dataset?',
#  '2.Who are the top three directors with the most content in the dataset?',
#  '3.Which country has produced the highest number of movies and TV shows combined in the dataset?',
#  '4.What is the average duration of Movies in the dataset?',
#  '5.What are the top three genres by the number of titles in the dataset?',
#  '6.What is the oldest Movie or TV Show in the dataset?',
#  '7.What is the distribution of content ratings in the dataset?']

# %% [markdown]
# 1.What is the distribution of content types in the dataset?

# %%
content_type_distribution = df['type'].value_counts()
print("Distribution of Content Types:")
print(content_type_distribution)
# Out:
# Distribution of Content Types:
# type
# Movie    788
# Name: count, dtype: int64

# %%
data.type.value_counts().plot(kind = 'bar', color=["red", "blue"])
plt.title("content type Values")
plt.xlabel("0 = Movies, 1= Tv Shows")
plt.ylabel("Amount");

# %%
data.type.value_counts().plot(kind='pie', figsize=(8, 6), colors=['blue', 'lightgreen'])
plt.legend(["Movie", "Tv shows"]);

# %% [markdown]
# 2.Who are the top three directors with the most content in the dataset?

# %%
top_three_directors = df['director'].value_counts().head(3)
print("Top Three Directors with the Most Content:")
print(top_three_directors)
# Out:
# Top Three Directors with the Most Content:
# director
# Paul Hoen           16
# John Lasseter       14
# Robert Stevenson    12
# Name: count, dtype: int64

# %%
top_three_directors = pd.DataFrame({'count': [10, 20, 30]}, index=['Director A', 'Director B', 'Director C'])
plt.figure(figsize=(8, 4))
colors = ['red', 'green', 'blue']
sns.barplot(x=top_three_directors.index, y='count', data=top_three_directors, palette=colors)
plt.xlabel('Director')
plt.ylabel('Number of Titles')
plt.title('Top Three Directors with Most Content')
plt.show()
# Out:
# <ipython-input-37-b01a7d6da3bc>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_three_directors.index, y='count', data=top_three_directors, palette=colors)

# %% [markdown]
# 3.Which country has produced the highest number of movies and TV shows combined in the dataset?

# %%
top_country = df['country'].value_counts().idxmax()
top_country_count = df['country'].value_counts().max()
print(f"The country with the highest number of movies and TV shows combined is {top_country} with {top_country_count} titles.")
# Out:
# The country with the highest number of movies and TV shows combined is United States with 631 titles.

# %%
top_countries.plot(kind='bar', color='purple')
plt.title('Top 10 Countries by Number of Productions')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 4.What is the average duration of Movies in the dataset?

# %%
movies_df = df[df['type'] == 'Movie']
average_duration = movies_df['duration'].str.extract('(\d+)').astype(int).mean()
print(f"The average duration of Movies is {average_duration[0]} minutes")
# Out:
# The average duration of Movies is 82.7994923857868 minutes

# %%
movies_df['duration'].hist(bins=20, color='black')
plt.title('Distribution of Movie Durations')
plt.xlabel('Duration (minutes)')
plt.ylabel('Number of Movies')
plt.show()

# %% [markdown]
# 5.What are the top three genres by the number of titles in the dataset?

# %%
genres = df['listed_in'].str.split(', ')
genres_exploded = genres.explode()
top_genres = genres_exploded.value_counts().head(3)
print("Top Three Genres by Number of Titles:")
print(top_genres)
# Out:
# Top Three Genres by Number of Titles:
# listed_in
# Family              400
# Comedy              329
# Action-Adventure    284
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))
colors = ['pink','purple','violet']
plt.pie(top_genres, labels=top_genres.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title('Top Three Genres by Number of Titles')
plt.show()

# %% [markdown]
# 6.What is the oldest Movie or TV Show in the dataset?

# %%
oldest_title = df.loc[df['release_year'].idxmin(), ['title', 'release_year', 'type']]
print(f"The oldest title in the dataset is '{oldest_title['title']}', a {oldest_title['type']} released in {oldest_title['release_year'].year}.")
# Out:
# The oldest title in the dataset is 'Steamboat Willie', a Movie released in 1928.

# %%
df['release_year'].dt.year.hist(bins=50, color='brown')
plt.title('Distribution of Release Years')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.axvline(df['release_year'].dt.year.min(), color='black', linestyle='dashed', linewidth=2)
plt.show()

# %% [markdown]
# 7.What is the distribution of content ratings in the dataset?

# %%
rating_counts = df['rating'].value_counts()
print(rating_counts)
# Out:
# rating
# G           218
# PG          215
# TV-G        156
# TV-PG       102
# PG-13        60
# TV-Y7        21
# TV-14        12
# TV-Y7-FV      3
# TV-Y          1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
rating_counts.plot(kind='bar', color='purple')
plt.title('Distribution of Content Ratings')
plt.xlabel('Rating')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Time Series Analysis for Forecasting Trends and Seasonality**

# %%
df.set_index('release_year', inplace=True)
df['title'].resample('Y').count().plot()
plt.title('Number of Titles Released Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# **Sentiment Analysis or Text Mining on Unstructured Data**

# %%
from textblob import TextBlob
df['sentiment'] = df['description'].apply(lambda x: TextBlob(x).sentiment.polarity)
print(df['sentiment'].describe())
df['sentiment'].hist()
plt.title('Sentiment Analysis of Titles')
plt.xlabel('Sentiment Polarity')
plt.ylabel('Frequency')
plt.show()
# Out:
# count    788.000000
# mean       0.078621
# std        0.299613
# min       -1.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.206771
# max        1.000000
# Name: sentiment, dtype: float64

# %% [markdown]
# **Clustering or Classification Techniques for Segmentation and Pattern Recognition**

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
features = ['sentiment']
X = df[features]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(X_scaled)
plt.figure(figsize=(10, 6))
sns.violinplot(x='cluster', y='sentiment', data=df, palette='muted')
plt.title('K-Means Clustering of Titles (Violin Plot)')
plt.xlabel('Cluster')
plt.ylabel('Sentiment Polarity')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# <ipython-input-67-1f483a20d0e0>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='cluster', y='sentiment', data=df, palette='muted')

# %% [markdown]
# **Classification Techniques**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
X = df[['sentiment']]
y = df['cluster']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9324894514767933

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='purple', alpha=0.5)
plt.title('Actual vs Predicted Clusters')
plt.xlabel('Actual Cluster')
plt.ylabel('Predicted Cluster')
plt.show()
